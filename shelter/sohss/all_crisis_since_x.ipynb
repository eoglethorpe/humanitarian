# %%
"""for pulling down data from hr.info API on response level and sending to CSV"""

import urllib.request, json
import csv
import itertools
import math

import grequests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#pulling data

def pull_indiv_rw(data):
    """
    return all individual crisis data, exclude ones that don't have a 200 status code.
    
    pull into a df and return, then that gets merged with the existing df
    """
    hrefz = data['rw_gen.href']

    def exception_handler(request, exception):
         print('Bad URL for ' + request)

    resps = []
    it = 200
    for v in range(0, len(hrefz), it):
        print('Pulling individual for hrefs to ' + str(v))
        rs = (grequests.get(ref) for ref in hrefz[v : v+it])
        resps += grequests.map(rs, exception_handler = exception_handler)
    
    resps = [json.loads(r.content) for r in resps if r.status_code == 200]
        
    return json_normalize(resps)[['data', 'href', 'totalCount']].add_prefix('rw_gen.')
#     return json_normalize(resps, ['totalCount', 'data', 'href']).add_prefix('rw_gen.')

def fetch_api_rw(maxv = None):
    """
    pull down all API info for RW general crisis and return as dataframe.
    
    maxv = (start_val, end_val)
    """
    data = []    
    
    if maxv:
        start = maxv[0]
        fin = maxv[1]
        step = min(fin - start, 1000)
    
    else:
        start = 0
        fin = json.loads(urllib.request.urlopen("https://api.reliefweb.int/v1/" \
                                   "disasters?appname=vocabulary&preset=external").read().decode())['totalCount']
        step = 1000
        
    for i in range(start, fin, step):
        with urllib.request.urlopen("https://api.reliefweb.int/v1/disasters?appname=vocabulary"
                                    "&preset=external&limit={0}&offset={1}"
                                    .format(min(step, fin - i), i)) as url:
            data += json.loads(url.read().decode())['data']


    ret = json_normalize(data).add_prefix('rw_gen.')
    
    assert(len(ret) == fin - start)
    print('pulling down from rw entry count of: ' + str(len(ret)))
    return ret

# %%
r.to_csv('rw_out.csv')

# %%
nd = rw(test = None, year = 2005)

r = nd.master_pull()

r.to_excel('out.xlsx', sheet_name = 'rw')
# Out:
# 3021
# pulling down from rw entry count of: 3021
# Pulling individual for hrefs to 0
# Pulling individual for hrefs to 200
# Pulling individual for hrefs to 400
# Pulling individual for hrefs to 600
# Pulling individual for hrefs to 800
# Pulling individual for hrefs to 1000
# Pulling individual for hrefs to 1200
# Pulling individual for hrefs to 1400
# Pulling individual for hrefs to 1600
# ***missing fields for https://api.reliefweb.int/v1/disasters/6854
# ***missing fields for https://api.reliefweb.int/v1/disasters/6797
# ***missing fields for https://api.reliefweb.int/v1/disasters/6792
# ***missing fields for https://api.reliefweb.int/v1/disasters/6729
# ***missing fields for https://api.reliefweb.int/v1/disasters/6789
# ***missing fields for https://api.reliefweb.int/v1/disasters/6745
# ***missing fields for https://api.reliefweb.int/v1/disasters/6720
# ***missing fields for https://api.reliefweb.int/v1/disasters/6726
# ***missing fields for https://api.reliefweb.int/v1/disasters/6735
# ***missing fields for https://api.reliefweb.int/v1/disasters/6752
# ***missing fields for https://api.reliefweb.int/v1/disasters/6740
# ***missing fields for https://api.reliefweb.int/v1/disasters/6738
# ***missing fields for https://api.reliefweb.int/v1/disasters/6753
# ***missing fields for https://api.reliefweb.int/v1/disasters/6325
# ***missing fields for https://api.reliefweb.int/v1/disasters/6182
# ***missing fields for https://api.reliefweb.int/v1/disasters/5353
# ***missing fields for https://api.reliefweb.int/v1/disasters/6461
# ***missing fields for https://api.reliefweb.int/v1/disasters/6475
# ***missing fields for https://api.reliefweb.int/v1/disasters/5724
# ***missing fields for https://api.reliefweb.int/v1/disasters/6409
# ***missing fields for https://api.reliefweb.int/v1/disasters/5279
# ***missing fields for https://api.reliefweb.int/v1/disasters/5927
# ***missing fields for https://api.reliefweb.int/v1/disasters/6017
# ***missing fields for https://api.reliefweb.int/v1/disasters/4994
# ***missing fields for https://api.reliefweb.int/v1/disasters/4991
# ***missing fields for https://api.reliefweb.int/v1/disasters/6184
# ***missing fields for https://api.reliefweb.int/v1/disasters/6448
# ***missing fields for https://api.reliefweb.int/v1/disasters/5002
# ***missing fields for https://api.reliefweb.int/v1/disasters/5601
# ***missing fields for https://api.reliefweb.int/v1/disasters/4907
# ***missing fields for https://api.reliefweb.int/v1/disasters/5965
# ***missing fields for https://api.reliefweb.int/v1/disasters/4892
# ***missing fields for https://api.reliefweb.int/v1/disasters/6557
# ***missing fields for https://api.reliefweb.int/v1/disasters/6525
# ***missing fields for https://api.reliefweb.int/v1/disasters/4875
# ***missing fields for https://api.reliefweb.int/v1/disasters/6247
# ***missing fields for https://api.reliefweb.int/v1/disasters/6216
# ***missing fields for https://api.reliefweb.int/v1/disasters/5792
# ***missing fields for https://api.reliefweb.int/v1/disasters/5092
# ***missing fields for https://api.reliefweb.int/v1/disasters/4774
# ***missing fields for https://api.reliefweb.int/v1/disasters/4872
# ***missing fields for https://api.reliefweb.int/v1/disasters/5829
# ***missing fields for https://api.reliefweb.int/v1/disasters/4922
# ***missing fields for https://api.reliefweb.int/v1/disasters/5192
# ***missing fields for https://api.reliefweb.int/v1/disasters/4914
# ***missing fields for https://api.reliefweb.int/v1/disasters/5095
# ***missing fields for https://api.reliefweb.int/v1/disasters/6652
# ***missing fields for https://api.reliefweb.int/v1/disasters/5954
# ***missing fields for https://api.reliefweb.int/v1/disasters/5365
# ***missing fields for https://api.reliefweb.int/v1/disasters/5286
# ***missing fields for https://api.reliefweb.int/v1/disasters/5230
# ***missing fields for https://api.reliefweb.int/v1/disasters/5626
# ***missing fields for https://api.reliefweb.int/v1/disasters/5185
# ***missing fields for https://api.reliefweb.int/v1/disasters/5637
# ***missing fields for https://api.reliefweb.int/v1/disasters/4709
# ***missing fields for https://api.reliefweb.int/v1/disasters/4926
# ***missing fields for https://api.reliefweb.int/v1/disasters/4860
# ***missing fields for https://api.reliefweb.int/v1/disasters/5873
# ***missing fields for https://api.reliefweb.int/v1/disasters/6379
# ***missing fields for https://api.reliefweb.int/v1/disasters/5332
# ***missing fields for https://api.reliefweb.int/v1/disasters/6226
# ***missing fields for https://api.reliefweb.int/v1/disasters/6131
# ***missing fields for https://api.reliefweb.int/v1/disasters/5675
# ***missing fields for https://api.reliefweb.int/v1/disasters/5463
# ***missing fields for https://api.reliefweb.int/v1/disasters/6278
# ***missing fields for https://api.reliefweb.int/v1/disasters/4791
# ***missing fields for https://api.reliefweb.int/v1/disasters/6188
# ***missing fields for https://api.reliefweb.int/v1/disasters/6183
# ***missing fields for https://api.reliefweb.int/v1/disasters/5464
# ***missing fields for https://api.reliefweb.int/v1/disasters/4915
# ***missing fields for https://api.reliefweb.int/v1/disasters/5448
# ***missing fields for https://api.reliefweb.int/v1/disasters/6627
# ***missing fields for https://api.reliefweb.int/v1/disasters/6434
# ***missing fields for https://api.reliefweb.int/v1/disasters/6541
# ***missing fields for https://api.reliefweb.int/v1/disasters/5413
# ***missing fields for https://api.reliefweb.int/v1/disasters/6177
# ***missing fields for https://api.reliefweb.int/v1/disasters/4780
# ***missing fields for https://api.reliefweb.int/v1/disasters/4950
# ***missing fields for https://api.reliefweb.int/v1/disasters/5854
# ***missing fields for https://api.reliefweb.int/v1/disasters/5343
# ***missing fields for https://api.reliefweb.int/v1/disasters/5595
# ***missing fields for https://api.reliefweb.int/v1/disasters/5106
# ***missing fields for https://api.reliefweb.int/v1/disasters/5360
# ***missing fields for https://api.reliefweb.int/v1/disasters/5700
# ***missing fields for https://api.reliefweb.int/v1/disasters/5614
# ***missing fields for https://api.reliefweb.int/v1/disasters/4832
# ***missing fields for https://api.reliefweb.int/v1/disasters/4801
# ***missing fields for https://api.reliefweb.int/v1/disasters/6070
# ***missing fields for https://api.reliefweb.int/v1/disasters/6180
# ***missing fields for https://api.reliefweb.int/v1/disasters/6169
# ***missing fields for https://api.reliefweb.int/v1/disasters/6389
# ***missing fields for https://api.reliefweb.int/v1/disasters/5401
# ***missing fields for https://api.reliefweb.int/v1/disasters/5791
# ***missing fields for https://api.reliefweb.int/v1/disasters/6415
# ***missing fields for https://api.reliefweb.int/v1/disasters/5029
# ***missing fields for https://api.reliefweb.int/v1/disasters/5819
# ***missing fields for https://api.reliefweb.int/v1/disasters/6060
# ***missing fields for https://api.reliefweb.int/v1/disasters/6584
# ***missing fields for https://api.reliefweb.int/v1/disasters/4793
# ***missing fields for https://api.reliefweb.int/v1/disasters/5538
# ***missing fields for https://api.reliefweb.int/v1/disasters/6009
# ***missing fields for https://api.reliefweb.int/v1/disasters/5015
# ***missing fields for https://api.reliefweb.int/v1/disasters/4812
# ***missing fields for https://api.reliefweb.int/v1/disasters/5890
# ***missing fields for https://api.reliefweb.int/v1/disasters/5691
# ***missing fields for https://api.reliefweb.int/v1/disasters/6173
# ***missing fields for https://api.reliefweb.int/v1/disasters/5751
# ***missing fields for https://api.reliefweb.int/v1/disasters/6006
# ***missing fields for https://api.reliefweb.int/v1/disasters/5460
# ***missing fields for https://api.reliefweb.int/v1/disasters/5161
# ***missing fields for https://api.reliefweb.int/v1/disasters/5550
# ***missing fields for https://api.reliefweb.int/v1/disasters/5289
# ***missing fields for https://api.reliefweb.int/v1/disasters/5949
# ***missing fields for https://api.reliefweb.int/v1/disasters/5784
# ***missing fields for https://api.reliefweb.int/v1/disasters/6094
# ***missing fields for https://api.reliefweb.int/v1/disasters/5845
# ***missing fields for https://api.reliefweb.int/v1/disasters/6410
# ***missing fields for https://api.reliefweb.int/v1/disasters/6476
# ***missing fields for https://api.reliefweb.int/v1/disasters/4622
# ***missing fields for https://api.reliefweb.int/v1/disasters/5579
# ***missing fields for https://api.reliefweb.int/v1/disasters/6229
# ***missing fields for https://api.reliefweb.int/v1/disasters/5776
# ***missing fields for https://api.reliefweb.int/v1/disasters/5085
# ***missing fields for https://api.reliefweb.int/v1/disasters/5716
# ***missing fields for https://api.reliefweb.int/v1/disasters/4916
# ***missing fields for https://api.reliefweb.int/v1/disasters/5726
# ***missing fields for https://api.reliefweb.int/v1/disasters/6660
# ***missing fields for https://api.reliefweb.int/v1/disasters/5238
# ***missing fields for https://api.reliefweb.int/v1/disasters/5194
# ***missing fields for https://api.reliefweb.int/v1/disasters/6160
# ***missing fields for https://api.reliefweb.int/v1/disasters/6105
# ***missing fields for https://api.reliefweb.int/v1/disasters/6293
# ***missing fields for https://api.reliefweb.int/v1/disasters/5696
# ***missing fields for https://api.reliefweb.int/v1/disasters/4708
# ***missing fields for https://api.reliefweb.int/v1/disasters/5207
# ***missing fields for https://api.reliefweb.int/v1/disasters/6666
# ***missing fields for https://api.reliefweb.int/v1/disasters/4911
# ***missing fields for https://api.reliefweb.int/v1/disasters/5530
# ***missing fields for https://api.reliefweb.int/v1/disasters/5471
# ***missing fields for https://api.reliefweb.int/v1/disasters/5051
# ***missing fields for https://api.reliefweb.int/v1/disasters/5371
# ***missing fields for https://api.reliefweb.int/v1/disasters/5210
# ***missing fields for https://api.reliefweb.int/v1/disasters/5578
# ***missing fields for https://api.reliefweb.int/v1/disasters/4788
# ***missing fields for https://api.reliefweb.int/v1/disasters/6174
# ***missing fields for https://api.reliefweb.int/v1/disasters/5871
# ***missing fields for https://api.reliefweb.int/v1/disasters/5068
# ***missing fields for https://api.reliefweb.int/v1/disasters/6010
# ***missing country fields for 0    https://api.reliefweb.int/v1/countries/254
# Name: fields.primary_country.href, dtype: object
# before: 6
# ['Since its emergence in April 2009, pandemic influenza A(H1N1) 2009 virus affected all parts of the world, causing the first influenza pandemic since 1968. Following the observation that 1 or 2 epidemic periods had occurred in most countries and in most WHO Regions, WHO declared on 10 Aug 2010 that the world was moving into the post-pandemic period. ([WHO, 18 Feb 2011](https://reliefweb.int/node/389128))', 'https://reliefweb.int/disaster/ep-2009-000084-mex', 200, 'World', 'wld', 'https://api.reliefweb.int/v1/countries/254']
# should be: 8
# 6
# ***missing fields for https://api.reliefweb.int/v1/disasters/5789
# ***missing fields for https://api.reliefweb.int/v1/disasters/6116
# ***missing fields for https://api.reliefweb.int/v1/disasters/5857
# ***missing fields for https://api.reliefweb.int/v1/disasters/5546
# ***missing fields for https://api.reliefweb.int/v1/disasters/6568
# ***missing fields for https://api.reliefweb.int/v1/disasters/6397
# ***missing fields for https://api.reliefweb.int/v1/disasters/6683
# ***missing fields for https://api.reliefweb.int/v1/disasters/5477
# ***missing fields for https://api.reliefweb.int/v1/disasters/6599
# ***missing fields for https://api.reliefweb.int/v1/disasters/5096
# ***missing fields for https://api.reliefweb.int/v1/disasters/5056
# ***missing fields for https://api.reliefweb.int/v1/disasters/5352
# ***missing fields for https://api.reliefweb.int/v1/disasters/6234
# ***missing fields for https://api.reliefweb.int/v1/disasters/5625
# ***missing fields for https://api.reliefweb.int/v1/disasters/4781
# ***missing fields for https://api.reliefweb.int/v1/disasters/5003
# ***missing fields for https://api.reliefweb.int/v1/disasters/5651
# ***missing fields for https://api.reliefweb.int/v1/disasters/5787
# ***missing fields for https://api.reliefweb.int/v1/disasters/5100
# ***missing fields for https://api.reliefweb.int/v1/disasters/4802
# ***missing fields for https://api.reliefweb.int/v1/disasters/6047
# ***missing fields for https://api.reliefweb.int/v1/disasters/5181
# ***missing fields for https://api.reliefweb.int/v1/disasters/4834
# ***missing fields for https://api.reliefweb.int/v1/disasters/5441
# ***missing fields for https://api.reliefweb.int/v1/disasters/6267
# ***missing fields for https://api.reliefweb.int/v1/disasters/4971
# ***missing fields for https://api.reliefweb.int/v1/disasters/6027
# ***missing fields for https://api.reliefweb.int/v1/disasters/6181
# ***missing fields for https://api.reliefweb.int/v1/disasters/6139
# ***missing fields for https://api.reliefweb.int/v1/disasters/6103
# ***missing fields for https://api.reliefweb.int/v1/disasters/4921
# ***missing fields for https://api.reliefweb.int/v1/disasters/5542
# ***missing fields for https://api.reliefweb.int/v1/disasters/4849
# ***missing fields for https://api.reliefweb.int/v1/disasters/6621
# ***missing fields for https://api.reliefweb.int/v1/disasters/5677
# ***missing fields for https://api.reliefweb.int/v1/disasters/5986
# ***missing fields for https://api.reliefweb.int/v1/disasters/6268
# ***missing fields for https://api.reliefweb.int/v1/disasters/4785
# ***missing fields for https://api.reliefweb.int/v1/disasters/4636
# ***missing fields for https://api.reliefweb.int/v1/disasters/5320
# ***missing fields for https://api.reliefweb.int/v1/disasters/5050
# ***missing fields for https://api.reliefweb.int/v1/disasters/4661
# ***missing fields for https://api.reliefweb.int/v1/disasters/6014
# ***missing fields for https://api.reliefweb.int/v1/disasters/6395
# ***missing fields for https://api.reliefweb.int/v1/disasters/5985
# ***missing fields for https://api.reliefweb.int/v1/disasters/5943
# ***missing fields for https://api.reliefweb.int/v1/disasters/5564
# ***missing fields for https://api.reliefweb.int/v1/disasters/5322
# ***missing fields for https://api.reliefweb.int/v1/disasters/5209
# ***missing fields for https://api.reliefweb.int/v1/disasters/5733
# ***missing fields for https://api.reliefweb.int/v1/disasters/6137
# ***missing fields for https://api.reliefweb.int/v1/disasters/4726
# ***missing fields for https://api.reliefweb.int/v1/disasters/5783
# ***missing fields for https://api.reliefweb.int/v1/disasters/5575
# ***missing fields for https://api.reliefweb.int/v1/disasters/5796
# ***missing fields for https://api.reliefweb.int/v1/disasters/5043
# ***missing fields for https://api.reliefweb.int/v1/disasters/5607
# ***missing fields for https://api.reliefweb.int/v1/disasters/5349
# ***missing fields for https://api.reliefweb.int/v1/disasters/5714
# ***missing fields for https://api.reliefweb.int/v1/disasters/6245
# ***missing fields for https://api.reliefweb.int/v1/disasters/6407
# ***missing fields for https://api.reliefweb.int/v1/disasters/6069
# ***missing fields for https://api.reliefweb.int/v1/disasters/4861
# ***missing fields for https://api.reliefweb.int/v1/disasters/5242
# ***missing fields for https://api.reliefweb.int/v1/disasters/4703
# ***missing fields for https://api.reliefweb.int/v1/disasters/5766
# ***missing fields for https://api.reliefweb.int/v1/disasters/6192
# ***missing fields for https://api.reliefweb.int/v1/disasters/4799
# ***missing fields for https://api.reliefweb.int/v1/disasters/5952
# ***missing fields for https://api.reliefweb.int/v1/disasters/5222
# ***missing fields for https://api.reliefweb.int/v1/disasters/5057
# ***missing fields for https://api.reliefweb.int/v1/disasters/4638
# ***missing fields for https://api.reliefweb.int/v1/disasters/6535
# ***missing fields for https://api.reliefweb.int/v1/disasters/6455
# ***missing fields for https://api.reliefweb.int/v1/disasters/4983
# ***missing fields for https://api.reliefweb.int/v1/disasters/5108
# ***missing fields for https://api.reliefweb.int/v1/disasters/6016
# ***missing fields for https://api.reliefweb.int/v1/disasters/6186
# ***missing fields for https://api.reliefweb.int/v1/disasters/6165
# ***missing fields for https://api.reliefweb.int/v1/disasters/6294
# ***missing fields for https://api.reliefweb.int/v1/disasters/5304
# ***missing fields for https://api.reliefweb.int/v1/disasters/6649
# ***missing fields for https://api.reliefweb.int/v1/disasters/6043
# ***missing fields for https://api.reliefweb.int/v1/disasters/5269
# ***missing fields for https://api.reliefweb.int/v1/disasters/5527
# ***missing fields for https://api.reliefweb.int/v1/disasters/5124
# ***missing fields for https://api.reliefweb.int/v1/disasters/6480
# ***missing fields for https://api.reliefweb.int/v1/disasters/4625
# ***missing fields for https://api.reliefweb.int/v1/disasters/5078
# ***missing fields for https://api.reliefweb.int/v1/disasters/6124
# ***missing fields for https://api.reliefweb.int/v1/disasters/5351
# ***missing fields for https://api.reliefweb.int/v1/disasters/5810
# ***missing fields for https://api.reliefweb.int/v1/disasters/4739
# ***missing fields for https://api.reliefweb.int/v1/disasters/6526
# ***missing fields for https://api.reliefweb.int/v1/disasters/6672
# ***missing fields for https://api.reliefweb.int/v1/disasters/6057
# ***missing fields for https://api.reliefweb.int/v1/disasters/5676
# ***missing fields for https://api.reliefweb.int/v1/disasters/5437
# ***missing fields for https://api.reliefweb.int/v1/disasters/6450
# ***missing fields for https://api.reliefweb.int/v1/disasters/5864
# ***missing fields for https://api.reliefweb.int/v1/disasters/4965
# ***missing fields for https://api.reliefweb.int/v1/disasters/5170
# ***missing fields for https://api.reliefweb.int/v1/disasters/5869
# ***missing fields for https://api.reliefweb.int/v1/disasters/6250
# ***missing fields for https://api.reliefweb.int/v1/disasters/5384
# ***missing fields for https://api.reliefweb.int/v1/disasters/5066
# ***missing fields for https://api.reliefweb.int/v1/disasters/5408
# ***missing fields for https://api.reliefweb.int/v1/disasters/6252
# ***missing fields for https://api.reliefweb.int/v1/disasters/5110
# ***missing fields for https://api.reliefweb.int/v1/disasters/5576
# ***missing fields for https://api.reliefweb.int/v1/disasters/6338
# ***missing fields for https://api.reliefweb.int/v1/disasters/5615
# ***missing fields for https://api.reliefweb.int/v1/disasters/4714
# ***missing fields for https://api.reliefweb.int/v1/disasters/5683
# ***missing fields for https://api.reliefweb.int/v1/disasters/4777
# ***missing fields for https://api.reliefweb.int/v1/disasters/5664
# ***missing fields for https://api.reliefweb.int/v1/disasters/6460
# ***missing fields for https://api.reliefweb.int/v1/disasters/5388
# ***missing fields for https://api.reliefweb.int/v1/disasters/6565
# ***missing fields for https://api.reliefweb.int/v1/disasters/6241
# ***missing fields for https://api.reliefweb.int/v1/disasters/6352
# ***missing fields for https://api.reliefweb.int/v1/disasters/5310
# ***missing fields for https://api.reliefweb.int/v1/disasters/5793
# ***missing fields for https://api.reliefweb.int/v1/disasters/6067
# ***missing fields for https://api.reliefweb.int/v1/disasters/5582
# ***missing fields for https://api.reliefweb.int/v1/disasters/5058
# ***missing fields for https://api.reliefweb.int/v1/disasters/5624
# ***missing fields for https://api.reliefweb.int/v1/disasters/5431
# ***missing fields for https://api.reliefweb.int/v1/disasters/6254
# ***missing fields for https://api.reliefweb.int/v1/disasters/5942
# ***missing fields for https://api.reliefweb.int/v1/disasters/6089
# ***missing fields for https://api.reliefweb.int/v1/disasters/4969
# ***missing fields for https://api.reliefweb.int/v1/disasters/5882
# ***missing fields for https://api.reliefweb.int/v1/disasters/6185
# ***missing fields for https://api.reliefweb.int/v1/disasters/6478
# ***missing fields for https://api.reliefweb.int/v1/disasters/6355
# ***missing fields for https://api.reliefweb.int/v1/disasters/6345
# ***missing fields for https://api.reliefweb.int/v1/disasters/4690
# ***missing fields for https://api.reliefweb.int/v1/disasters/6121
# ***missing fields for https://api.reliefweb.int/v1/disasters/6570
# ***missing fields for https://api.reliefweb.int/v1/disasters/6290
# ***missing fields for https://api.reliefweb.int/v1/disasters/5404
# ***missing fields for https://api.reliefweb.int/v1/disasters/6362
# ***missing fields for https://api.reliefweb.int/v1/disasters/5886
# ***missing fields for https://api.reliefweb.int/v1/disasters/6414
# ***missing fields for https://api.reliefweb.int/v1/disasters/6644
# ***missing fields for https://api.reliefweb.int/v1/disasters/6421
# ***missing fields for https://api.reliefweb.int/v1/disasters/5859
# ***missing fields for https://api.reliefweb.int/v1/disasters/6671
# ***missing fields for https://api.reliefweb.int/v1/disasters/4654
# ***missing fields for https://api.reliefweb.int/v1/disasters/6138
# ***missing fields for https://api.reliefweb.int/v1/disasters/4865
# ***missing fields for https://api.reliefweb.int/v1/disasters/6340
# ***missing fields for https://api.reliefweb.int/v1/disasters/4630
# ***missing fields for https://api.reliefweb.int/v1/disasters/5410
# ***missing fields for https://api.reliefweb.int/v1/disasters/5738
# ***missing fields for https://api.reliefweb.int/v1/disasters/5306
# ***missing fields for https://api.reliefweb.int/v1/disasters/5103
# ***missing fields for https://api.reliefweb.int/v1/disasters/5761
# ***missing fields for https://api.reliefweb.int/v1/disasters/5488
# ***missing fields for https://api.reliefweb.int/v1/disasters/4717
# ***missing fields for https://api.reliefweb.int/v1/disasters/5430
# ***missing fields for https://api.reliefweb.int/v1/disasters/6470
# ***missing fields for https://api.reliefweb.int/v1/disasters/6370
# ***missing fields for https://api.reliefweb.int/v1/disasters/5702
# ***missing fields for https://api.reliefweb.int/v1/disasters/4647
# ***missing fields for https://api.reliefweb.int/v1/disasters/6074
# ***missing fields for https://api.reliefweb.int/v1/disasters/6316
# ***missing fields for https://api.reliefweb.int/v1/disasters/4752
# ***missing fields for https://api.reliefweb.int/v1/disasters/6647
# ***missing fields for https://api.reliefweb.int/v1/disasters/4797
# ***missing fields for https://api.reliefweb.int/v1/disasters/6007
# ***missing fields for https://api.reliefweb.int/v1/disasters/6613
# ***missing fields for https://api.reliefweb.int/v1/disasters/5284
# ***missing fields for https://api.reliefweb.int/v1/disasters/5168
# ***missing fields for https://api.reliefweb.int/v1/disasters/5996
# ***missing fields for https://api.reliefweb.int/v1/disasters/5655
# ***missing fields for https://api.reliefweb.int/v1/disasters/6657
# ***missing fields for https://api.reliefweb.int/v1/disasters/6310
# ***missing fields for https://api.reliefweb.int/v1/disasters/6429
# ***missing fields for https://api.reliefweb.int/v1/disasters/5609
# ***missing fields for https://api.reliefweb.int/v1/disasters/5196
# ***missing fields for https://api.reliefweb.int/v1/disasters/6324
# ***missing fields for https://api.reliefweb.int/v1/disasters/5083
# ***missing fields for https://api.reliefweb.int/v1/disasters/4731
# ***missing fields for https://api.reliefweb.int/v1/disasters/6574
# ***missing fields for https://api.reliefweb.int/v1/disasters/6111
# ***missing fields for https://api.reliefweb.int/v1/disasters/5759
# ***missing fields for https://api.reliefweb.int/v1/disasters/4701
# ***missing fields for https://api.reliefweb.int/v1/disasters/6637
# ***missing fields for https://api.reliefweb.int/v1/disasters/6620
# ***missing fields for https://api.reliefweb.int/v1/disasters/5914
# ***missing fields for https://api.reliefweb.int/v1/disasters/5768
# ***missing fields for https://api.reliefweb.int/v1/disasters/6032
# ***missing fields for https://api.reliefweb.int/v1/disasters/6521
# ***missing fields for https://api.reliefweb.int/v1/disasters/6115
# ***missing fields for https://api.reliefweb.int/v1/disasters/5364
# ***missing fields for https://api.reliefweb.int/v1/disasters/6431
# ***missing fields for https://api.reliefweb.int/v1/disasters/5179
# ***missing fields for https://api.reliefweb.int/v1/disasters/6175
# ***missing fields for https://api.reliefweb.int/v1/disasters/6151
# ***missing fields for https://api.reliefweb.int/v1/disasters/5841
# ***missing fields for https://api.reliefweb.int/v1/disasters/4730
# ***missing fields for https://api.reliefweb.int/v1/disasters/4645
# ***missing fields for https://api.reliefweb.int/v1/disasters/5071
# ***missing fields for https://api.reliefweb.int/v1/disasters/6388
# ***missing fields for https://api.reliefweb.int/v1/disasters/4789
# ***missing fields for https://api.reliefweb.int/v1/disasters/5662
# ***missing fields for https://api.reliefweb.int/v1/disasters/6319
# ***missing fields for https://api.reliefweb.int/v1/disasters/6262
# ***missing fields for https://api.reliefweb.int/v1/disasters/5184
# ***missing fields for https://api.reliefweb.int/v1/disasters/6435
# ***missing fields for https://api.reliefweb.int/v1/disasters/5950
# ***missing fields for https://api.reliefweb.int/v1/disasters/5017
# ***missing fields for https://api.reliefweb.int/v1/disasters/6195
# ***missing fields for https://api.reliefweb.int/v1/disasters/4939
# ***missing fields for https://api.reliefweb.int/v1/disasters/4984
# ***missing fields for https://api.reliefweb.int/v1/disasters/4937
# ***missing fields for https://api.reliefweb.int/v1/disasters/4974
# ***missing fields for https://api.reliefweb.int/v1/disasters/5946
# ***missing fields for https://api.reliefweb.int/v1/disasters/5119
# ***missing fields for https://api.reliefweb.int/v1/disasters/5605
# ***missing fields for https://api.reliefweb.int/v1/disasters/5701
# ***missing fields for https://api.reliefweb.int/v1/disasters/5411
# ***missing fields for https://api.reliefweb.int/v1/disasters/4964
# ***missing fields for https://api.reliefweb.int/v1/disasters/6509
# ***missing fields for https://api.reliefweb.int/v1/disasters/4998
# ***missing fields for https://api.reliefweb.int/v1/disasters/5480
# ***missing fields for https://api.reliefweb.int/v1/disasters/5969
# ***missing fields for https://api.reliefweb.int/v1/disasters/4869
# ***missing fields for https://api.reliefweb.int/v1/disasters/6134
# ***missing fields for https://api.reliefweb.int/v1/disasters/5338
# ***missing fields for https://api.reliefweb.int/v1/disasters/6600
# ***missing fields for https://api.reliefweb.int/v1/disasters/5548
# ***missing fields for https://api.reliefweb.int/v1/disasters/6547
# ***missing fields for https://api.reliefweb.int/v1/disasters/5554
# ***missing fields for https://api.reliefweb.int/v1/disasters/5505
# ***missing fields for https://api.reliefweb.int/v1/disasters/4644
# ***missing fields for https://api.reliefweb.int/v1/disasters/5718
# ***missing fields for https://api.reliefweb.int/v1/disasters/4750
# ***missing fields for https://api.reliefweb.int/v1/disasters/6237
# ***missing fields for https://api.reliefweb.int/v1/disasters/6381
# ***missing fields for https://api.reliefweb.int/v1/disasters/5880
# ***missing fields for https://api.reliefweb.int/v1/disasters/5135
# ***missing fields for https://api.reliefweb.int/v1/disasters/4859
# ***missing fields for https://api.reliefweb.int/v1/disasters/5600
# ***missing fields for https://api.reliefweb.int/v1/disasters/6699
# ***missing fields for https://api.reliefweb.int/v1/disasters/5831
# ***missing fields for https://api.reliefweb.int/v1/disasters/5520
# ***missing fields for https://api.reliefweb.int/v1/disasters/6504
# ***missing fields for https://api.reliefweb.int/v1/disasters/5808
# ***missing fields for https://api.reliefweb.int/v1/disasters/5741
# ***missing fields for https://api.reliefweb.int/v1/disasters/5725
# ***missing fields for https://api.reliefweb.int/v1/disasters/6153
# ***missing fields for https://api.reliefweb.int/v1/disasters/5027
# ***missing fields for https://api.reliefweb.int/v1/disasters/6055
# ***missing fields for https://api.reliefweb.int/v1/disasters/6492
# ***missing fields for https://api.reliefweb.int/v1/disasters/5312
# ***missing fields for https://api.reliefweb.int/v1/disasters/6713
# ***missing fields for https://api.reliefweb.int/v1/disasters/5913
# ***missing fields for https://api.reliefweb.int/v1/disasters/4972
# ***missing fields for https://api.reliefweb.int/v1/disasters/6510
# ***missing fields for https://api.reliefweb.int/v1/disasters/4631
# ***missing fields for https://api.reliefweb.int/v1/disasters/5981
# ***missing fields for https://api.reliefweb.int/v1/disasters/6443
# ***missing fields for https://api.reliefweb.int/v1/disasters/4751
# ***missing fields for https://api.reliefweb.int/v1/disasters/5348
# ***missing fields for https://api.reliefweb.int/v1/disasters/6573
# ***missing fields for https://api.reliefweb.int/v1/disasters/6266
# ***missing fields for https://api.reliefweb.int/v1/disasters/4782
# ***missing fields for https://api.reliefweb.int/v1/disasters/4676
# ***missing fields for https://api.reliefweb.int/v1/disasters/6128
# ***missing fields for https://api.reliefweb.int/v1/disasters/6026
# ***missing fields for https://api.reliefweb.int/v1/disasters/5957
# ***missing fields for https://api.reliefweb.int/v1/disasters/6287
# ***missing fields for https://api.reliefweb.int/v1/disasters/4663
# ***missing fields for https://api.reliefweb.int/v1/disasters/5577
# ***missing fields for https://api.reliefweb.int/v1/disasters/5129
# ***missing fields for https://api.reliefweb.int/v1/disasters/6125
# ***missing fields for https://api.reliefweb.int/v1/disasters/5919
# ***missing fields for https://api.reliefweb.int/v1/disasters/5055
# ***missing fields for https://api.reliefweb.int/v1/disasters/6401
# ***missing fields for https://api.reliefweb.int/v1/disasters/6349
# ***missing fields for https://api.reliefweb.int/v1/disasters/6605
# ***missing fields for https://api.reliefweb.int/v1/disasters/5547
# ***missing fields for https://api.reliefweb.int/v1/disasters/6668
# ***missing fields for https://api.reliefweb.int/v1/disasters/5447
# ***missing fields for https://api.reliefweb.int/v1/disasters/6495
# ***missing fields for https://api.reliefweb.int/v1/disasters/5329
# ***missing fields for https://api.reliefweb.int/v1/disasters/4794
# ***missing fields for https://api.reliefweb.int/v1/disasters/5694
# ***missing fields for https://api.reliefweb.int/v1/disasters/6005
# ***missing fields for https://api.reliefweb.int/v1/disasters/5781
# ***missing fields for https://api.reliefweb.int/v1/disasters/5620
# ***missing fields for https://api.reliefweb.int/v1/disasters/5445
# ***missing fields for https://api.reliefweb.int/v1/disasters/5585
# ***missing fields for https://api.reliefweb.int/v1/disasters/5245
# ***missing fields for https://api.reliefweb.int/v1/disasters/5905
# ***missing fields for https://api.reliefweb.int/v1/disasters/5221
# ***missing fields for https://api.reliefweb.int/v1/disasters/5863
# ***missing fields for https://api.reliefweb.int/v1/disasters/6263
# ***missing fields for https://api.reliefweb.int/v1/disasters/6018
# ***missing fields for https://api.reliefweb.int/v1/disasters/5610
# ***missing fields for https://api.reliefweb.int/v1/disasters/6376
# ***missing fields for https://api.reliefweb.int/v1/disasters/6469
# ***missing fields for https://api.reliefweb.int/v1/disasters/6655
# ***missing fields for https://api.reliefweb.int/v1/disasters/4749
# ***missing fields for https://api.reliefweb.int/v1/disasters/4803
# ***missing fields for https://api.reliefweb.int/v1/disasters/4772
# ***missing fields for https://api.reliefweb.int/v1/disasters/6291
# ***missing fields for https://api.reliefweb.int/v1/disasters/6190
# ***missing fields for https://api.reliefweb.int/v1/disasters/5355
# ***missing fields for https://api.reliefweb.int/v1/disasters/5150
# ***missing fields for https://api.reliefweb.int/v1/disasters/5758
# ***missing fields for https://api.reliefweb.int/v1/disasters/6646
# ***missing fields for https://api.reliefweb.int/v1/disasters/5211
# ***missing fields for https://api.reliefweb.int/v1/disasters/5201
# ***missing fields for https://api.reliefweb.int/v1/disasters/6248
# ***missing fields for https://api.reliefweb.int/v1/disasters/5215
# ***missing fields for https://api.reliefweb.int/v1/disasters/5218
# ***missing fields for https://api.reliefweb.int/v1/disasters/6430
# ***missing fields for https://api.reliefweb.int/v1/disasters/4905
# ***missing fields for https://api.reliefweb.int/v1/disasters/5848
# ***missing fields for https://api.reliefweb.int/v1/disasters/5689
# ***missing fields for https://api.reliefweb.int/v1/disasters/5453
# ***missing fields for https://api.reliefweb.int/v1/disasters/6356
# ***missing fields for https://api.reliefweb.int/v1/disasters/5363
# ***missing fields for https://api.reliefweb.int/v1/disasters/4941
# ***missing fields for https://api.reliefweb.int/v1/disasters/6347
# ***missing fields for https://api.reliefweb.int/v1/disasters/6597
# ***missing fields for https://api.reliefweb.int/v1/disasters/6501
# ***missing fields for https://api.reliefweb.int/v1/disasters/5227
# ***missing fields for https://api.reliefweb.int/v1/disasters/4735
# ***missing fields for https://api.reliefweb.int/v1/disasters/5995
# ***missing fields for https://api.reliefweb.int/v1/disasters/5533
# ***missing fields for https://api.reliefweb.int/v1/disasters/6549
# ***missing fields for https://api.reliefweb.int/v1/disasters/5133
# ***missing fields for https://api.reliefweb.int/v1/disasters/5785
# ***missing fields for https://api.reliefweb.int/v1/disasters/5334
# ***missing fields for https://api.reliefweb.int/v1/disasters/6327
# ***missing fields for https://api.reliefweb.int/v1/disasters/4943
# ***missing fields for https://api.reliefweb.int/v1/disasters/6048
# ***missing fields for https://api.reliefweb.int/v1/disasters/5559
# ***missing fields for https://api.reliefweb.int/v1/disasters/5911
# ***missing fields for https://api.reliefweb.int/v1/disasters/5754
# ***missing fields for https://api.reliefweb.int/v1/disasters/5114
# ***missing fields for https://api.reliefweb.int/v1/disasters/5867
# ***missing fields for https://api.reliefweb.int/v1/disasters/5377
# ***missing fields for https://api.reliefweb.int/v1/disasters/6225
# ***missing fields for https://api.reliefweb.int/v1/disasters/5474
# ***missing fields for https://api.reliefweb.int/v1/disasters/4693
# ***missing fields for https://api.reliefweb.int/v1/disasters/5091
# ***missing fields for https://api.reliefweb.int/v1/disasters/5099
# ***missing fields for https://api.reliefweb.int/v1/disasters/6109
# ***missing fields for https://api.reliefweb.int/v1/disasters/6511
# ***missing fields for https://api.reliefweb.int/v1/disasters/5814
# ***missing fields for https://api.reliefweb.int/v1/disasters/6623
# ***missing fields for https://api.reliefweb.int/v1/disasters/6711
# ***missing fields for https://api.reliefweb.int/v1/disasters/5250
# ***missing fields for https://api.reliefweb.int/v1/disasters/4910
# ***missing fields for https://api.reliefweb.int/v1/disasters/5955
# ***missing fields for https://api.reliefweb.int/v1/disasters/5409
# ***missing fields for https://api.reliefweb.int/v1/disasters/5126
# ***missing fields for https://api.reliefweb.int/v1/disasters/5795
# ***missing fields for https://api.reliefweb.int/v1/disasters/5160
# ***missing fields for https://api.reliefweb.int/v1/disasters/6596
# ***missing fields for https://api.reliefweb.int/v1/disasters/6622
# ***missing fields for https://api.reliefweb.int/v1/disasters/6491
# ***missing fields for https://api.reliefweb.int/v1/disasters/6021
# ***missing fields for https://api.reliefweb.int/v1/disasters/4695
# ***missing fields for https://api.reliefweb.int/v1/disasters/6598
# ***missing fields for https://api.reliefweb.int/v1/disasters/4940
# ***missing fields for https://api.reliefweb.int/v1/disasters/4857
# ***missing fields for https://api.reliefweb.int/v1/disasters/5397
# ***missing fields for https://api.reliefweb.int/v1/disasters/4617
# ***missing fields for https://api.reliefweb.int/v1/disasters/6675
# ***missing fields for https://api.reliefweb.int/v1/disasters/6087
# ***missing fields for https://api.reliefweb.int/v1/disasters/5902
# ***missing fields for https://api.reliefweb.int/v1/disasters/4928
# ***missing fields for https://api.reliefweb.int/v1/disasters/4683
# ***missing fields for https://api.reliefweb.int/v1/disasters/5635
# ***missing fields for https://api.reliefweb.int/v1/disasters/5540
# ***missing fields for https://api.reliefweb.int/v1/disasters/6551
# ***missing fields for https://api.reliefweb.int/v1/disasters/4961
# ***missing fields for https://api.reliefweb.int/v1/disasters/4722
# ***missing fields for https://api.reliefweb.int/v1/disasters/5551
# ***missing fields for https://api.reliefweb.int/v1/disasters/5865
# ***missing fields for https://api.reliefweb.int/v1/disasters/6277
# ***missing fields for https://api.reliefweb.int/v1/disasters/5962
# ***missing fields for https://api.reliefweb.int/v1/disasters/6576
# ***missing fields for https://api.reliefweb.int/v1/disasters/6583
# ***missing fields for https://api.reliefweb.int/v1/disasters/5011
# ***missing fields for https://api.reliefweb.int/v1/disasters/5568
# ***missing fields for https://api.reliefweb.int/v1/disasters/5904
# ***missing fields for https://api.reliefweb.int/v1/disasters/5327
# ***missing fields for https://api.reliefweb.int/v1/disasters/4786
# ***missing fields for https://api.reliefweb.int/v1/disasters/6447
# ***missing fields for https://api.reliefweb.int/v1/disasters/4723
# ***missing fields for https://api.reliefweb.int/v1/disasters/6590
# ***missing fields for https://api.reliefweb.int/v1/disasters/5378
# ***missing fields for https://api.reliefweb.int/v1/disasters/6312
# ***missing fields for https://api.reliefweb.int/v1/disasters/4759
# ***missing fields for https://api.reliefweb.int/v1/disasters/4885
# ***missing fields for https://api.reliefweb.int/v1/disasters/5847
# ***missing fields for https://api.reliefweb.int/v1/disasters/4677
# ***missing fields for https://api.reliefweb.int/v1/disasters/6273
# ***missing fields for https://api.reliefweb.int/v1/disasters/5968
# ***missing fields for https://api.reliefweb.int/v1/disasters/5122
# ***missing fields for https://api.reliefweb.int/v1/disasters/5486
# ***missing fields for https://api.reliefweb.int/v1/disasters/5251
# ***missing fields for https://api.reliefweb.int/v1/disasters/5259
# ***missing fields for https://api.reliefweb.int/v1/disasters/5385
# ***missing fields for https://api.reliefweb.int/v1/disasters/4773
# ***missing fields for https://api.reliefweb.int/v1/disasters/5293
# ***missing fields for https://api.reliefweb.int/v1/disasters/5861
# ***missing fields for https://api.reliefweb.int/v1/disasters/5667
# ***missing fields for https://api.reliefweb.int/v1/disasters/5307
# ***missing fields for https://api.reliefweb.int/v1/disasters/5246
# ***missing fields for https://api.reliefweb.int/v1/disasters/6592
# ***missing fields for https://api.reliefweb.int/v1/disasters/5331
# ***missing fields for https://api.reliefweb.int/v1/disasters/6053
# ***missing fields for https://api.reliefweb.int/v1/disasters/6700
# ***missing fields for https://api.reliefweb.int/v1/disasters/6529
# ***missing fields for https://api.reliefweb.int/v1/disasters/5296
# ***missing fields for https://api.reliefweb.int/v1/disasters/6533
# ***missing fields for https://api.reliefweb.int/v1/disasters/5928
# ***missing fields for https://api.reliefweb.int/v1/disasters/5283
# ***missing fields for https://api.reliefweb.int/v1/disasters/6167
# ***missing fields for https://api.reliefweb.int/v1/disasters/6546
# ***missing fields for https://api.reliefweb.int/v1/disasters/5587
# ***missing fields for https://api.reliefweb.int/v1/disasters/5735
# ***missing fields for https://api.reliefweb.int/v1/disasters/5569
# ***missing fields for https://api.reliefweb.int/v1/disasters/6068
# ***missing fields for https://api.reliefweb.int/v1/disasters/5067
# ***missing fields for https://api.reliefweb.int/v1/disasters/6626
# ***missing fields for https://api.reliefweb.int/v1/disasters/5432
# ***missing fields for https://api.reliefweb.int/v1/disasters/5382
# ***missing fields for https://api.reliefweb.int/v1/disasters/6490
# ***missing fields for https://api.reliefweb.int/v1/disasters/5874
# ***missing fields for https://api.reliefweb.int/v1/disasters/4906
# ***missing fields for https://api.reliefweb.int/v1/disasters/5686
# ***missing fields for https://api.reliefweb.int/v1/disasters/5061
# ***missing fields for https://api.reliefweb.int/v1/disasters/5502
# ***missing fields for https://api.reliefweb.int/v1/disasters/6382
# ***missing fields for https://api.reliefweb.int/v1/disasters/5134
# ***missing fields for https://api.reliefweb.int/v1/disasters/6684
# ***missing fields for https://api.reliefweb.int/v1/disasters/6633
# ***missing fields for https://api.reliefweb.int/v1/disasters/4876
# ***missing fields for https://api.reliefweb.int/v1/disasters/4945
# ***missing fields for https://api.reliefweb.int/v1/disasters/6155
# ***missing fields for https://api.reliefweb.int/v1/disasters/6130
# ***missing fields for https://api.reliefweb.int/v1/disasters/6342
# ***missing fields for https://api.reliefweb.int/v1/disasters/6424
# ***missing fields for https://api.reliefweb.int/v1/disasters/6080
# ***missing fields for https://api.reliefweb.int/v1/disasters/4805
# ***missing fields for https://api.reliefweb.int/v1/disasters/6616
# ***missing fields for https://api.reliefweb.int/v1/disasters/5153
# ***missing fields for https://api.reliefweb.int/v1/disasters/5004
# ***missing fields for https://api.reliefweb.int/v1/disasters/6375
# ***missing fields for https://api.reliefweb.int/v1/disasters/5750
# ***missing fields for https://api.reliefweb.int/v1/disasters/5852
# ***missing fields for https://api.reliefweb.int/v1/disasters/6523
# ***missing fields for https://api.reliefweb.int/v1/disasters/5817
# ***missing fields for https://api.reliefweb.int/v1/disasters/5586
# ***missing fields for https://api.reliefweb.int/v1/disasters/5824
# ***missing fields for https://api.reliefweb.int/v1/disasters/6544
# ***missing fields for https://api.reliefweb.int/v1/disasters/6022
# ***missing fields for https://api.reliefweb.int/v1/disasters/5628
# ***missing fields for https://api.reliefweb.int/v1/disasters/5497
# ***missing fields for https://api.reliefweb.int/v1/disasters/4649
# ***missing fields for https://api.reliefweb.int/v1/disasters/5762
# ***missing fields for https://api.reliefweb.int/v1/disasters/5241
# ***missing fields for https://api.reliefweb.int/v1/disasters/4870
# ***missing fields for https://api.reliefweb.int/v1/disasters/5693
# ***missing fields for https://api.reliefweb.int/v1/disasters/6062
# ***missing fields for https://api.reliefweb.int/v1/disasters/5870
# ***missing fields for https://api.reliefweb.int/v1/disasters/5228
# ***missing fields for https://api.reliefweb.int/v1/disasters/5436
# ***missing fields for https://api.reliefweb.int/v1/disasters/4819
# ***missing fields for https://api.reliefweb.int/v1/disasters/5383
# ***missing fields for https://api.reliefweb.int/v1/disasters/4862
# ***missing fields for https://api.reliefweb.int/v1/disasters/5794
# ***missing fields for https://api.reliefweb.int/v1/disasters/6708
# ***missing fields for https://api.reliefweb.int/v1/disasters/5652
# ***missing fields for https://api.reliefweb.int/v1/disasters/5292
# ***missing fields for https://api.reliefweb.int/v1/disasters/6714
# ***missing fields for https://api.reliefweb.int/v1/disasters/5379
# ***missing fields for https://api.reliefweb.int/v1/disasters/4712
# ***missing fields for https://api.reliefweb.int/v1/disasters/5038
# ***missing fields for https://api.reliefweb.int/v1/disasters/5976
# ***missing fields for https://api.reliefweb.int/v1/disasters/4809
# ***missing fields for https://api.reliefweb.int/v1/disasters/6049
# ***missing fields for https://api.reliefweb.int/v1/disasters/4995
# ***missing fields for https://api.reliefweb.int/v1/disasters/6221
# ***missing fields for https://api.reliefweb.int/v1/disasters/5036
# ***missing fields for https://api.reliefweb.int/v1/disasters/5496
# ***missing fields for https://api.reliefweb.int/v1/disasters/6075
# ***missing fields for https://api.reliefweb.int/v1/disasters/6119
# ***missing fields for https://api.reliefweb.int/v1/disasters/6123
# ***missing fields for https://api.reliefweb.int/v1/disasters/4977
# ***missing fields for https://api.reliefweb.int/v1/disasters/5836
# ***missing fields for https://api.reliefweb.int/v1/disasters/6256
# ***missing fields for https://api.reliefweb.int/v1/disasters/5142
# ***missing fields for https://api.reliefweb.int/v1/disasters/6636
# ***missing fields for https://api.reliefweb.int/v1/disasters/6686
# ***missing fields for https://api.reliefweb.int/v1/disasters/5224
# ***missing fields for https://api.reliefweb.int/v1/disasters/6211
# ***missing fields for https://api.reliefweb.int/v1/disasters/4798
# ***missing fields for https://api.reliefweb.int/v1/disasters/5631
# ***missing fields for https://api.reliefweb.int/v1/disasters/5475
# ***missing fields for https://api.reliefweb.int/v1/disasters/5257
# ***missing fields for https://api.reliefweb.int/v1/disasters/5893
# ***missing fields for https://api.reliefweb.int/v1/disasters/5086
# ***missing fields for https://api.reliefweb.int/v1/disasters/5722
# ***missing fields for https://api.reliefweb.int/v1/disasters/5901
# ***missing fields for https://api.reliefweb.int/v1/disasters/5838
# ***missing fields for https://api.reliefweb.int/v1/disasters/5636
# ***missing fields for https://api.reliefweb.int/v1/disasters/6507
# ***missing fields for https://api.reliefweb.int/v1/disasters/5244
# ***missing fields for https://api.reliefweb.int/v1/disasters/4664
# ***missing fields for https://api.reliefweb.int/v1/disasters/5489
# ***missing fields for https://api.reliefweb.int/v1/disasters/5478
# ***missing fields for https://api.reliefweb.int/v1/disasters/6385
# ***missing fields for https://api.reliefweb.int/v1/disasters/5435
# ***missing fields for https://api.reliefweb.int/v1/disasters/6503
# ***missing fields for https://api.reliefweb.int/v1/disasters/5891
# ***missing fields for https://api.reliefweb.int/v1/disasters/5010
# ***missing fields for https://api.reliefweb.int/v1/disasters/4909
# ***missing fields for https://api.reliefweb.int/v1/disasters/6073
# ***missing fields for https://api.reliefweb.int/v1/disasters/5157
# ***missing fields for https://api.reliefweb.int/v1/disasters/4988
# ***missing fields for https://api.reliefweb.int/v1/disasters/5951
# ***missing fields for https://api.reliefweb.int/v1/disasters/5972
# ***missing fields for https://api.reliefweb.int/v1/disasters/5907
# ***missing fields for https://api.reliefweb.int/v1/disasters/5062
# ***missing fields for https://api.reliefweb.int/v1/disasters/5025
# ***missing fields for https://api.reliefweb.int/v1/disasters/6670
# ***missing fields for https://api.reliefweb.int/v1/disasters/6466
# ***missing fields for https://api.reliefweb.int/v1/disasters/6161
# ***missing fields for https://api.reliefweb.int/v1/disasters/5984
# ***missing fields for https://api.reliefweb.int/v1/disasters/5375
# ***missing fields for https://api.reliefweb.int/v1/disasters/6052
# ***missing fields for https://api.reliefweb.int/v1/disasters/4981
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# <ipython-input-144-84235b233e35> in <module>()
#       3 r = nd.master_pull()
#       4
# ----> 5 r.to_excel('out.xlsx', sheet_name = 'rw')
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     650         writer.write_cells(formatted_cells, sheet_name,
#     651                            startrow=startrow, startcol=startcol,
# --> 652                            freeze_panes=freeze_panes)
#     653         if need_save:
#     654             writer.save()
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/pandas/io/excel.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#    1393                 column=startcol + cell.col + 1
#    1394             )
# -> 1395             xcell.value, fmt = self._value_with_fmt(cell.val)
#    1396             if fmt:
#    1397                 xcell.number_format = fmt
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/openpyxl/cell/cell.py in value(self, value)
#     290     def value(self, value):
#     291         """Set the value and infer type and display options."""
# --> 292         self._bind_value(value)
#     293
#     294     @property
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/openpyxl/cell/cell.py in _bind_value(self, value)
#     189
#     190         elif isinstance(value, STRING_TYPES):
# --> 191             value = self.check_string(value)
#     192             self.data_type = self.TYPE_STRING
#     193             if len(value) > 1 and value.startswith("="):
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/openpyxl/cell/cell.py in check_string(self, value)
#     154         value = value[:32767]
#     155         if next(ILLEGAL_CHARACTERS_RE.finditer(value), None):
# --> 156             raise IllegalCharacterError
#     157         return value
#     158
#
# IllegalCharacterError:

# %%
class rw(object):
    def t(self):
        pass
    
    def __init__(self, test, year):
        self.test = test
        self.data = None
        self.year = year

    def extract_date(self, val):
        name = val.replace(' ', '')[-7:]
        month = None
        year = None

        MIN_YEAR = 2005
        #if we don't have regular formatting, take just year
        if not name[0:3].isalpha():
            if not name[-4:].isnumeric():
                print("***bad year: " + name)
            else:
                year = int(name[-4:])
        else:
            month = name[:3]
            year = int(name[-4:])

        if year:
            if year >= MIN_YEAR:
                return [month, year]

        return (None, None)

    def get_date(self):
        self.data['rw_gen.month'] = None
        self.data['rw_gen.year'] = None
        self.data[['rw_gen.month', 'rw_gen.year']] = self.data.apply(lambda x: 
                                                            pd.Series(self.extract_date(x['rw_gen.fields.name'])), axis = 1)

        self.data = self.data[pd.notnull(self.data['rw_gen.year'])]
        self.data['rw_gen.year'] = self.data['rw_gen.year'].astype(int)

    def trim_nm(self):

        def trim(v):
            s_val = None

            if len(v.split('-')) != 1:
                s_val = '-'
            elif len(v.split('–')) != 1:
                s_val = '–' 

            if s_val:
                return v.split(s_val)[0]
            else:
                return v

        self.data['rw_gen.fields.name'] = self.data.apply(lambda x: trim(x['rw_gen.fields.name']), axis = 1)

    def rm_old(self):
        self.data = self.data.drop(self.data[self.data['rw_gen.year'] < self.year].index)
        print('trim data length: ' + len(self.data))

    def _get_spec_crisis_lamb(self, v):
        ret = []

        if v['rw_gen.totalCount'] != 1:
            print('***wrong totalCount ' + str(v))

        j = json_normalize(v['rw_gen.data'][0])

        #add in top level data compents
        try:
            ret += [j[ent.split('data.')[1]][0] for ent in self.new_cols_top]
            
        except:
            ret += [None] * len(self.new_cols_top)

        #add in data.fields info. entry be like:
        """
            {'href': 'https://api.reliefweb.int/v1/countries/255',
             'id': 255,
             'iso3': 'yem',
             'location': {'lat': 15.94, 'lon': 47.62},
             'name': 'Yemen',
             'primary': True}
            primary = None
        """
        
        #add in other columns
        for v in j['fields.country'][0]:
            if 'primary' in v:
                primary = v
                break        

        #bad news if no primary
        if not primary:
            print('*** no primary! ' + str(v))
            ret = [None] * (len(self.all_cols) - len(self.new_cols_top))
            
        else:
            try:
                rollback = ret
                
                #also add in other cols
                ret.append(len(j['fields.country'][0]))

                ret += [primary[c] for c in ['name', 'iso3', 'href']]
                ret.append(primary['location']['lat'])
                ret.append(primary['location']['lon'])
                
            except:
                ret = rollback + [None] * (len(rollback) - (len(self.all_cols) - len(self.new_cols_top)))
        
        return ret
    
    def get_spec_crisis(self):
        """
        merge relevant crisis level data
        """
        
        l = pull_indiv_rw(self.data)
        
        l['rw_gen.totalCount'] = l['rw_gen.totalCount'].astype(int)

        self.new_cols_top = ['data.fields.description',
                    'data.fields.url_alias']

        self.other_cols = ['num_country']
        
        self.new_cols_country = ['data.fields.country.name', 
                            'data.fields.country.iso', 
                            'data.fields.country.href',
                            'data.fields.country.location_lat', 
                            'data.fields.country.location_long']

        self.all_cols = self.new_cols_top + self.other_cols + self.new_cols_country

        for v in self.all_cols:
            l[v] = None
        
        l[self.all_cols] = l.apply(lambda x : pd.Series(self._get_spec_crisis_lamb(x)), axis = 1)

        #drop unnecessary columns, cleanup
        l = l.drop('rw_gen.data', axis = 1)
        l = l.drop('rw_gen.totalCount', axis = 1)
        l['num_country'] = l['num_country'].astype(int)

        self.data = self.data.merge(l, how = 'left', on = 'rw_gen.href')
        
    def master_pull(self):
        """take crises only after certain year, add month_crisis: mmm, and year_crisis: yyyy to each crisis's entry

            names are either in format of:
                MMM YYYY
                OR
                YYYY-YYYY

            if not in first format, check to see if end year > 2005
        """
        #only pull some data if test
        if self.test:
            self.data = fetch_api_rw(self.test)
        else:
            self.data = fetch_api_rw()

        #do things to primary rw data
        self.get_date()
        self.rm_old()
        self.trim_nm()
        
        #do crisiswise pull
        self.get_spec_crisis()
        
        return self.data

# %%
def write():
    d = master_pull()
    with open('crises.csv', 'w') as csv_file:
        out = csv.writer(csv_file, delimiter=',')
        out.writerow(('crisis_nm', 'date_month', 'date_year', 'glide', 'url'))
        for v in d:
            out.writerow([v['fields']['name'], v['fields']['month_crisis'], v['fields']['year_crisis'], v['fields']['glide'], v['href']])
            
write()
