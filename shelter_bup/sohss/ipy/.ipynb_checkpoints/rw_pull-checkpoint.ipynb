# %%
"""for pulling down data from hr.info API on response level and sending to CSV"""

import urllib.request, json
import csv
import itertools
import math
from collections import OrderedDict

import grequests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#pulling data

def pull_indiv_rw(data):
    """
    return all individual crisis data, exclude ones that don't have a 200 status code.
    
    pull into a df and return, then that gets merged with the existing df
    """
    hrefz = data['rw_gen.href']

    def exception_handler(request, exception):
         print('Bad URL for ' + str(request))

    resps = []
    it = 200
    for v in range(0, len(hrefz), it):
        print('Pulling individual for hrefs to ' + str(v))
        rs = (grequests.get(ref) for ref in hrefz[v : v+it])
        resps += grequests.map(rs, exception_handler = exception_handler)
    
    resps = [json.loads(r.content) for r in resps if r.status_code == 200]
        
    return json_normalize(resps)[['data', 'href', 'totalCount']].add_prefix('rw_gen.')
#     return json_normalize(resps, ['totalCount', 'data', 'href']).add_prefix('rw_gen.')

def fetch_api_rw(maxv = None):
    """
    pull down all API info for RW general crisis and return as dataframe.
    
    maxv = (start_val, end_val)
    """
    data = []    
    
    if maxv:
        start = maxv[0]
        fin = maxv[1]
        step = min(fin - start, 1000)
    
    else:
        start = 0
        fin = json.loads(urllib.request.urlopen("https://api.reliefweb.int/v1/" \
                                   "disasters?appname=vocabulary&preset=external").read().decode())['totalCount']
        step = 1000
        
    for i in range(start, fin, step):
        with urllib.request.urlopen("https://api.reliefweb.int/v1/disasters?appname=vocabulary"
                                    "&preset=external&limit={0}&offset={1}"
                                    .format(min(step, fin - i), i)) as url:

            data += json.loads(url.read().decode())['data']


    ret = json_normalize(data).add_prefix('rw_gen.')
    
    assert(len(ret) == fin - start)
    print('pulling down from rw entry count of: ' + str(len(ret)))
    return ret

# %%
rs = (grequests.get(ref) for ref in ['https://api.reliefweb.int/v1/disasters/45654'])
resps = grequests.map(rs)

resps = [json.loads(r.content) for r in resps if r.status_code == 200]


j = json_normalize(resps[0]['data'])
# Out:
#                                       fields.country  fields.current  \
# 0  [{'href': 'https://api.reliefweb.int/v1/countr...            True
#
#          fields.date.created  \
# 0  2018-04-18T00:00:00+00:00
#
#                                   fields.description  \
# 0  Heavy rainfall occurred in different parts of ...
#
#                              fields.description-html  fields.featured  \
# 0  <p>Heavy rainfall occurred in different parts ...            False
#
#          fields.glide  fields.id                  fields.name  \
# 0  FL-2018-000043-TZA      45654  Tanzania: Floods - Apr 2018
#
#                   fields.primary_country.href  ...    \
# 0  https://api.reliefweb.int/v1/countries/244  ...
#
#    fields.primary_type.code fields.primary_type.id  fields.primary_type.name  \
# 0                        FL                   4611                     Flood
#
#                              fields.profile.overview  \
# 0  Heavy rainfall occurred in different parts of ...
#
#                         fields.profile.overview-html fields.status  \
# 0  <p>Heavy rainfall occurred in different parts ...       current
#
#                                          fields.type  \
# 0  [{'id': 4611, 'name': 'Flood', 'code': 'FL', '...
#
#                                   fields.url  \
# 0  https://reliefweb.int/taxonomy/term/45654
#
#                                     fields.url_alias     id
# 0  https://reliefweb.int/disaster/fl-2018-000043-tza  45654
#
# [1 rows x 26 columns]

# %%
# Out:
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=1&offset=10
# pulling down from rw entry count of: 1
# trim data length: 1
# Pulling individual for hrefs to 0
# Pulling individual for hrefs to 0
#                                          rw_gen.data  \
# 0  [{'fields': {'id': 45654, 'name': 'Tanzania: F...
#
#                                     rw_gen.href  rw_gen.totalCount
# 0  https://api.reliefweb.int/v1/disasters/45654                  1

# %%
nd = rw(test = None, year = 2005)

r = nd.master_pull()

r
# Out:
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=1000&offset=0
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=1000&offset=1000
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=1000&offset=2000
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=21&offset=3000
# pulling down from rw entry count of: 3021
# trim data length: 1701
# Pulling individual for hrefs to 0
# Pulling individual for hrefs to 200
# Pulling individual for hrefs to 400
# Pulling individual for hrefs to 600
# Pulling individual for hrefs to 800
# Pulling individual for hrefs to 1000
# Pulling individual for hrefs to 1200
# Pulling individual for hrefs to 1400
# Pulling individual for hrefs to 1600
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-309e2e06c829> in <module>()
#       1 nd = rw(test = None, year = 2005)
#       2
# ----> 3 r = nd.master_pull()
#       4
#       5 r
#
# <ipython-input-81-3ee0b1ca453d> in master_pull(self)
#     174
#     175         #do crisiswise pull
# --> 176         self.get_spec_crisis()
#     177
#     178         return self.data
#
# <ipython-input-81-3ee0b1ca453d> in get_spec_crisis(self)
#     143             l[v] = None
#     144
# --> 145         l[self.all_cols] = l.apply(lambda x : pd.Series(self._get_spec_crisis_lamb(x)), axis = 1)
#     146
#     147         #drop unnecessary columns, cleanup
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3111             self._setitem_frame(key, value)
#    3112         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3113             self._setitem_array(key, value)
#    3114         else:
#    3115             # set column
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3133             if isinstance(value, DataFrame):
#    3134                 if len(value.columns) != len(key):
# -> 3135                     raise ValueError('Columns must be same length as key')
#    3136                 for k1, k2 in zip(key, value.columns):
#    3137                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
len(l)
# Out:
# 30

# %%
l
# Out:
#                                            rw_gen.data  \
# 0    [{'fields': {'id': 6291, 'name': 'Solomon Isla...
# 1    [{'fields': {'id': 6190, 'name': 'Argentina: F...
# 2    [{'fields': {'id': 5355, 'name': 'OPT: Waste W...
# 3    [{'fields': {'id': 5150, 'name': 'Haiti: Flood...
# 4    [{'fields': {'id': 5758, 'name': 'South Asia: ...
# 5    [{'fields': {'id': 6646, 'name': 'Afghanistan:...
# 6    [{'fields': {'id': 5936, 'name': 'Madagascar: ...
# 7    [{'fields': {'id': 5211, 'name': 'Indonesia: E...
# 8    [{'fields': {'id': 5201, 'name': 'Indonesia: L...
# 9    [{'fields': {'id': 6248, 'name': 'Paraguay: De...
# 10   [{'fields': {'id': 5215, 'name': 'Swaziland: H...
# 11   [{'fields': {'id': 6654, 'name': 'Southern Afr...
# 12   [{'fields': {'id': 5218, 'name': 'Fiji: Floods...
# 13   [{'fields': {'id': 6430, 'name': 'Indonesia: F...
# 14   [{'fields': {'id': 4905, 'name': 'USA: Florida...
# 15   [{'fields': {'id': 5848, 'name': 'Argentina: F...
# 16   [{'fields': {'id': 5689, 'name': 'Indonesia: N...
# 17   [{'fields': {'id': 5453, 'name': 'Bolivia: Flo...
# 18   [{'fields': {'id': 5519, 'name': 'Southern Afr...
# 19   [{'fields': {'id': 6356, 'name': 'Comoros: Kar...
# 20   [{'fields': {'id': 5363, 'name': 'Peru: Floods...
# 21   [{'fields': {'id': 4941, 'name': 'Sri Lanka: F...
# 22   [{'fields': {'id': 6347, 'name': 'Montserrat: ...
# 23   [{'fields': {'id': 6597, 'name': 'Brazil: Muds...
# 24   [{'fields': {'id': 6501, 'name': 'Philippines:...
# 25   [{'fields': {'id': 5227, 'name': 'South Asia: ...
# 26   [{'fields': {'id': 5832, 'name': 'Madagascar: ...
# 27   [{'fields': {'id': 4735, 'name': 'El Salvador:...
# 28   [{'fields': {'id': 5995, 'name': 'Kyrgyzstan: ...
# 29   [{'fields': {'id': 5533, 'name': 'Taiwan (Chin...
# ..                                                 ...
# 200  [{'fields': {'id': 5496, 'name': 'Haiti: Côte-...
# 201  [{'fields': {'id': 6075, 'name': 'India: Flood...
# 202  [{'fields': {'id': 6119, 'name': 'Kyrgyzstan: ...
# 203  [{'fields': {'id': 6123, 'name': 'Afghanistan:...
# 204  [{'fields': {'id': 4977, 'name': 'Afghanistan:...
# 205  [{'fields': {'id': 5836, 'name': 'Bulgaria: Fl...
# 206  [{'fields': {'id': 6256, 'name': 'Guatemala: M...
# 207  [{'fields': {'id': 5142, 'name': 'Chile: Earth...
# 208  [{'fields': {'id': 6636, 'name': 'Papua New Gu...
# 209  [{'fields': {'id': 6686, 'name': 'Tajikistan: ...
# 210  [{'fields': {'id': 5224, 'name': 'China: Flood...
# 211  [{'fields': {'id': 6211, 'name': 'Romania: Flo...
# 212  [{'fields': {'id': 4798, 'name': 'El Salvador:...
# 213  [{'fields': {'id': 5631, 'name': 'Tajikistan: ...
# 214  [{'fields': {'id': 5475, 'name': 'Yemen: Flood...
# 215  [{'fields': {'id': 5257, 'name': 'Somalia: Hea...
# 216  [{'fields': {'id': 5893, 'name': 'Georgia: Flo...
# 217  [{'fields': {'id': 5086, 'name': 'Indonesia: F...
# 218  [{'fields': {'id': 5722, 'name': 'Horn of Afri...
# 219  [{'fields': {'id': 5901, 'name': 'Tanzania: Fl...
# 220  [{'fields': {'id': 5838, 'name': 'Serbia and M...
# 221  [{'fields': {'id': 5636, 'name': 'Djibouti: Dr...
# 222  [{'fields': {'id': 6507, 'name': 'Comoros: Kar...
# 223  [{'fields': {'id': 5668, 'name': 'Senegal: Cho...
# 224  [{'fields': {'id': 5244, 'name': 'Indonesia: M...
# 225  [{'fields': {'id': 4664, 'name': 'Indonesia: E...
# 226  [{'fields': {'id': 5489, 'name': 'Bangladesh: ...
# 227  [{'fields': {'id': 5478, 'name': 'Afghanistan:...
# 228  [{'fields': {'id': 6385, 'name': 'Serbia and M...
# 229  [{'fields': {'id': 5435, 'name': 'Angola: Floo...
#
#                                      rw_gen.href  rw_gen.totalCount
# 0    https://api.reliefweb.int/v1/disasters/6291                  1
# 1    https://api.reliefweb.int/v1/disasters/6190                  1
# 2    https://api.reliefweb.int/v1/disasters/5355                  1
# 3    https://api.reliefweb.int/v1/disasters/5150                  1
# 4    https://api.reliefweb.int/v1/disasters/5758                  1
# 5    https://api.reliefweb.int/v1/disasters/6646                  1
# 6    https://api.reliefweb.int/v1/disasters/5936                  1
# 7    https://api.reliefweb.int/v1/disasters/5211                  1
# 8    https://api.reliefweb.int/v1/disasters/5201                  1
# 9    https://api.reliefweb.int/v1/disasters/6248                  1
# 10   https://api.reliefweb.int/v1/disasters/5215                  1
# 11   https://api.reliefweb.int/v1/disasters/6654                  1
# 12   https://api.reliefweb.int/v1/disasters/5218                  1
# 13   https://api.reliefweb.int/v1/disasters/6430                  1
# 14   https://api.reliefweb.int/v1/disasters/4905                  1
# 15   https://api.reliefweb.int/v1/disasters/5848                  1
# 16   https://api.reliefweb.int/v1/disasters/5689                  1
# 17   https://api.reliefweb.int/v1/disasters/5453                  1
# 18   https://api.reliefweb.int/v1/disasters/5519                  1
# 19   https://api.reliefweb.int/v1/disasters/6356                  1
# 20   https://api.reliefweb.int/v1/disasters/5363                  1
# 21   https://api.reliefweb.int/v1/disasters/4941                  1
# 22   https://api.reliefweb.int/v1/disasters/6347                  1
# 23   https://api.reliefweb.int/v1/disasters/6597                  1
# 24   https://api.reliefweb.int/v1/disasters/6501                  1
# 25   https://api.reliefweb.int/v1/disasters/5227                  1
# 26   https://api.reliefweb.int/v1/disasters/5832                  1
# 27   https://api.reliefweb.int/v1/disasters/4735                  1
# 28   https://api.reliefweb.int/v1/disasters/5995                  1
# 29   https://api.reliefweb.int/v1/disasters/5533                  1
# ..                                           ...                ...
# 200  https://api.reliefweb.int/v1/disasters/5496                  1
# 201  https://api.reliefweb.int/v1/disasters/6075                  1
# 202  https://api.reliefweb.int/v1/disasters/6119                  1
# 203  https://api.reliefweb.int/v1/disasters/6123                  1
# 204  https://api.reliefweb.int/v1/disasters/4977                  1
# 205  https://api.reliefweb.int/v1/disasters/5836                  1
# 206  https://api.reliefweb.int/v1/disasters/6256                  1
# 207  https://api.reliefweb.int/v1/disasters/5142                  1
# 208  https://api.reliefweb.int/v1/disasters/6636                  1
# 209  https://api.reliefweb.int/v1/disasters/6686                  1
# 210  https://api.reliefweb.int/v1/disasters/5224                  1
# 211  https://api.reliefweb.int/v1/disasters/6211                  1
# 212  https://api.reliefweb.int/v1/disasters/4798                  1
# 213  https://api.reliefweb.int/v1/disasters/5631                  1
# 214  https://api.reliefweb.int/v1/disasters/5475                  1
# 215  https://api.reliefweb.int/v1/disasters/5257                  1
# 216  https://api.reliefweb.int/v1/disasters/5893                  1
# 217  https://api.reliefweb.int/v1/disasters/5086                  1
# 218  https://api.reliefweb.int/v1/disasters/5722                  1
# 219  https://api.reliefweb.int/v1/disasters/5901                  1
# 220  https://api.reliefweb.int/v1/disasters/5838                  1
# 221  https://api.reliefweb.int/v1/disasters/5636                  1
# 222  https://api.reliefweb.int/v1/disasters/6507                  1
# 223  https://api.reliefweb.int/v1/disasters/5668                  1
# 224  https://api.reliefweb.int/v1/disasters/5244                  1
# 225  https://api.reliefweb.int/v1/disasters/4664                  1
# 226  https://api.reliefweb.int/v1/disasters/5489                  1
# 227  https://api.reliefweb.int/v1/disasters/5478                  1
# 228  https://api.reliefweb.int/v1/disasters/6385                  1
# 229  https://api.reliefweb.int/v1/disasters/5435                  1
#
# [230 rows x 3 columns]

# %%
nd = rw(test = (1450,1680), year = 2005)
r = nd.master_pull()

l = pull_indiv_rw(r)
j = json_normalize(l['rw_gen.data'][0])


for p in l:
    print(json_normalize(p['rw_gen.data'][0]))
#     print(json_normalize(l['rw_gen.data'][0])['fields.country'][0])
#     for v in json_normalize(l['rw_gen.data'][0]):
#         print(v)
#         if 'primary' in v:
#             primary = v
#             break

print(j['fields.country'][0])
        
# [v for v in j.iteritems()]

j
# Out:
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=230&offset=1450
# pulling down from rw entry count of: 230
# trim data length: 230
# Pulling individual for hrefs to 0
# Pulling individual for hrefs to 200
# Pulling individual for hrefs to 0
# Pulling individual for hrefs to 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-184-fd8a29dd0708> in <module>()
#       7
#       8 for p in l:
# ----> 9     print(json_normalize(p['rw_gen.data'][0]))
#      10 #     print(json_normalize(l['rw_gen.data'][0])['fields.country'][0])
#      11 #     for v in json_normalize(l['rw_gen.data'][0]):
#
# TypeError: string indices must be integers

# %%
nd = rw(test = (1450,1480), year = 2005)
r = nd.master_pull()

l = pull_indiv_rw(r)
j = json_normalize(l['rw_gen.data'][0])
primary = None



for v in j['fields.country'][0]:
    if 'primary' in v:
        primary = v
        break

#bad news if no primary
if not primary:
    print('*** no primary! ' + str(v))
    ret = [None] * (len(self.all_cols) - len(self.new_cols_top))
    

as_int = lambda x : int(l[x])
as_is = lambda x : j[x][0] if x in j.columns else None
len_country = lambda x : len(j['fields.country']) if 'fields.country' in j else None

p = lambda x : None

get_vals = OrderedDict({
        'rw_gen.totalCount' : as_int,
        'fields.description' : as_is,
        'fields.url_alias' : as_is,
        'fields.primary_type.id' : as_is,
        'fields.primary_type.name' : as_is,
        'fields.primary_type.code' : as_is,
        'fields.country.name' : p,
        'fields.country.iso' : p,
        'fields.country.href' : p,
        'fields.country.location_lat' : p,
        'fields.country.location_long' : p,
        'num_country' : len_country})

ret = [get_vals[x](x) for x in get_vals] 

ret
# Out:
# https://api.reliefweb.int/v1/disasters?appname=vocabulary&preset=external&limit=30&offset=1450
# pulling down from rw entry count of: 30
# trim data length: 30
# Pulling individual for hrefs to 0
# Pulling individual for hrefs to 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-25ebc2bc115e> in <module>()
#      39         'num_country' : len_country})
#      40
# ---> 41 ret = [get_vals[x](x) for x in get_vals]
#      42
#      43 ret
#
# <ipython-input-165-25ebc2bc115e> in <listcomp>(.0)
#      39         'num_country' : len_country})
#      40
# ---> 41 ret = [get_vals[x](x) for x in get_vals]
#      42
#      43 ret
#
# <ipython-input-165-25ebc2bc115e> in <lambda>(x)
#      19
#      20
# ---> 21 as_int = lambda x : int(l[x])
#      22 as_is = lambda x : j[x][0] if x in j.columns else None
#      23 len_country = lambda x : len(j['fields.country']) if 'fields.country' in j else None
#
# ~/Documents/work/code/venv/p3/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     115             return converter(self.iloc[0])
#     116         raise TypeError("cannot convert the series to "
# --> 117                         "{0}".format(str(converter)))
#     118
#     119     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
j
# Out:
#                                       fields.country  fields.current  \
# 0  [{'href': 'https://api.reliefweb.int/v1/countr...            True
#
#          fields.date.created  \
# 0  2018-04-18T00:00:00+00:00
#
#                                   fields.description  \
# 0  Heavy rainfall occurred in different parts of ...
#
#                              fields.description-html  fields.featured  \
# 0  <p>Heavy rainfall occurred in different parts ...            False
#
#          fields.glide  fields.id                  fields.name  \
# 0  FL-2018-000043-TZA      45654  Tanzania: Floods - Apr 2018
#
#                   fields.primary_country.href  ...    \
# 0  https://api.reliefweb.int/v1/countries/244  ...
#
#    fields.primary_type.code fields.primary_type.id  fields.primary_type.name  \
# 0                        FL                   4611                     Flood
#
#                              fields.profile.overview  \
# 0  Heavy rainfall occurred in different parts of ...
#
#                         fields.profile.overview-html fields.status  \
# 0  <p>Heavy rainfall occurred in different parts ...       current
#
#                                          fields.type  \
# 0  [{'id': 4611, 'name': 'Flood', 'code': 'FL', '...
#
#                                   fields.url  \
# 0  https://reliefweb.int/taxonomy/term/45654
#
#                                     fields.url_alias     id
# 0  https://reliefweb.int/disaster/fl-2018-000043-tza  45654
#
# [1 rows x 26 columns]

# %%
    def _get_spec_crisis_lamb(self, v):
        global ret
        global j

        ret = []

        if v['rw_gen.totalCount'] != 1:
            print('***wrong totalCount ' + str(v))

        j = json_normalize(v['rw_gen.data'][0])

        #add in top level data compents
        try:
            ret += [j[ent.split('data.')[1]][0] for ent in self.new_cols_top]
            
        except:
            ret += [None] * len(self.new_cols_top)

        #add in data.fields info. entry be like:
        """
            {'href': 'https://api.reliefweb.int/v1/countries/255',
             'id': 255,
             'iso3': 'yem',
             'location': {'lat': 15.94, 'lon': 47.62},
             'name': 'Yemen',
             'primary': True}
            primary = None
        """
        
        #add in other columns
        for v in j['fields.country'][0]:
            if 'primary' in v:
                primary = v
                break

        #bad news if no primary
        if not primary:
            print('*** no primary! ' + str(v))
            ret = [None] * (len(self.all_cols) - len(self.new_cols_top))
            
        else:
            try:
                rollback = ret
                
                #also add in other cols
                ret.append(len(j['fields.country'][0]))

                ret += [primary[c] for c in ['name', 'iso3', 'href']]
                ret.append(primary['location']['lat'])
                ret.append(primary['location']['lon'])
                
            except:
                ret = rollback + [None] * (len(rollback) - (len(self.all_cols) - len(self.new_cols_top)))
                
        return ret
    
    def get_spec_crisis(self):
        """
        merge relevant crisis level data
        """
        
        l = pull_indiv_rw(self.data)
        
        l['rw_gen.totalCount'] = l['rw_gen.totalCount'].astype(int)

        self.new_cols_top = 'data.fields.description',
                            'data.fields.url_alias',
                            'data.primary_type.id',
                            'data.primary_type.name',
                            'data.primary_type.code'
                            ]
    
        self.other_cols = ['num_country']
        
        self.new_cols_country = 'data.fields.country.name', 
                                'data.fields.country.iso', 
                                'data.fields.country.href',
                                'data.fields.country.location_lat', 
                                'data.fields.country.location_long']

        self.all_cols = self.new_cols_top + self.other_cols + self.new_cols_country

        for v in self.all_cols:
            l[v] = None
        
        l[self.all_cols] = l.apply(lambda x : pd.Series(self._get_spec_crisis_lamb(x)), axis = 1)

        #drop unnecessary columns, cleanup
        l = l.drop('rw_gen.data', axis = 1)
        l = l.drop('rw_gen.totalCount', axis = 1)
        l['num_country'] = l['num_country'].astype(int)

        self.data = self.data.merge(l, how = 'left', on = 'rw_gen.href')

# %%
class rw(object):
    
    def __init__(self, test, year):
        self.test = test
        self.data = None
        self.year = year

    def extract_date(self, val):
        name = val.replace(' ', '')[-7:]
        month = None
        year = None

        MIN_YEAR = 2005
        #if we don't have regular formatting, take just year
        if not name[0:3].isalpha():
            if not name[-4:].isnumeric():
                print("***bad year: " + name)
            else:
                year = int(name[-4:])
        else:
            month = name[:3]
            year = int(name[-4:])

        if year:
            if year >= MIN_YEAR:
                return [month, year]

        return (None, None)

    def get_date(self):
        self.data['rw_gen.month'] = None
        self.data['rw_gen.year'] = None
        self.data[['rw_gen.month', 'rw_gen.year']] = self.data.apply(lambda x: 
                                                            pd.Series(self.extract_date(x['rw_gen.fields.name'])), axis = 1)

        self.data = self.data[pd.notnull(self.data['rw_gen.year'])]
        self.data['rw_gen.year'] = self.data['rw_gen.year'].astype(int)
        
    def trim_nm(self):

        def trim(v):
            s_val = None

            if len(v.split('-')) != 1:
                s_val = '-'
            elif len(v.split('–')) != 1:
                s_val = '–' 

            if s_val:
                return v.split(s_val)[0]
            else:
                return v

        self.data['rw_gen.fields.name'] = self.data.apply(lambda x: trim(x['rw_gen.fields.name']), axis = 1)

    def rm_old(self):
        self.data = self.data.drop(self.data[self.data['rw_gen.year'] < self.year].index)
        print('trim data length: ' + str(len(self.data)))

    def _get_spec_crisis_lamb(self, v):
        global ret
        global j

        ret = []
        
        to_int = lambda x : int(x)

        l['rw_gen.totalCount'] = l['rw_gen.totalCount'].astype(int)

        #name of col : func that gets its value
        get_vals = {
            'rw_gen.totalCount' : to_int
        }
        

        if get_vals['rw_gen.totalCount'] != 1:
            print('***wrong totalCount ' + str(v))

        j = json_normalize(v['rw_gen.data'][0])

        
        
        try:
            ret += [j[ent.split('data.')[1]][0] for ent in self.new_cols_top]
            
        except:
            ret += [None] * len(self.new_cols_top)

         

            
                
        ##########

        self.new_cols_top = ['data.fields.description',
                            'data.fields.url_alias',
                            'data.primary_type.id',
                            'data.primary_type.name',
                            'data.primary_type.code'
                            ]
    
        self.other_cols = ['num_country']
        
        self.new_cols_country = ['data.fields.country.name', 
                                'data.fields.country.iso', 
                                'data.fields.country.href',
                                'data.fields.country.location_lat', 
                                'data.fields.country.location_long']

        
        


        #add in data.fields info. entry be like:
        """
            {'href': 'https://api.reliefweb.int/v1/countries/255',
             'id': 255,
             'iso3': 'yem',
             'location': {'lat': 15.94, 'lon': 47.62},
             'name': 'Yemen',
             'primary': True}
            primary = None
        """
        
        #add in other columns
        for v in j['fields.country'][0]:
            if 'primary' in v:
                primary = v
                break

        #bad news if no primary
        if not primary:
            print('*** no primary! ' + str(v))
            ret = [None] * (len(self.all_cols) - len(self.new_cols_top))
            
        else:
            try:
                rollback = ret
                
                #also add in other cols
                ret.append(len(j['fields.country'][0]))

                ret += [primary[c] for c in ['name', 'iso3', 'href']]
                ret.append(primary['location']['lat'])
                ret.append(primary['location']['lon'])
                
            except:
                ret = rollback + [None] * (len(rollback) - (len(self.all_cols) - len(self.new_cols_top)))
                
        return ret
    
    def get_spec_crisis(self):
        """
        merge relevant crisis level data
        """
        
        l = pull_indiv_rw(self.data)
        
        to_int = lambda x : int(x)
        
        #name of col : func that gets its value
        get_vals = {
            'rw_gen.totalCount' : to_int
        }
         

            
                
        l['rw_gen.totalCount'] = l['rw_gen.totalCount'].astype(int)

        ##########

        self.new_cols_top = ['data.fields.description',
                            'data.fields.url_alias',
                            'data.primary_type.id',
                            'data.primary_type.name',
                            'data.primary_type.code'
                            ]
    
        self.other_cols = ['num_country']
        
        self.new_cols_country = ['data.fields.country.name', 
                                'data.fields.country.iso', 
                                'data.fields.country.href',
                                'data.fields.country.location_lat', 
                                'data.fields.country.location_long']

        self.all_cols = self.new_cols_top + self.other_cols + self.new_cols_country

        for v in self.all_cols:
            l[v] = None
        
        l[self.all_cols] = l.apply(lambda x : pd.Series(self._get_spec_crisis_lamb(x)), axis = 1)

        #drop unnecessary columns, cleanup
        l = l.drop('rw_gen.data', axis = 1)
        l = l.drop('rw_gen.totalCount', axis = 1)
        l['num_country'] = l['num_country'].astype(int)

        self.data = self.data.merge(l, how = 'left', on = 'rw_gen.href')
        
    def master_pull(self):
        """take crises only after certain year, add month_crisis: mmm, and year_crisis: yyyy to each crisis's entry

            names are either in format of:
                MMM YYYY
                OR
                YYYY-YYYY

            if not in first format, check to see if end year > 2005
        """
        #only pull some data if test
        if self.test:
            self.data = fetch_api_rw(self.test)
        else:
            self.data = fetch_api_rw()

        #do things to primary rw data
        self.get_date()
        self.rm_old()
        self.trim_nm()
        
        #do crisiswise pull
        self.get_spec_crisis()
        
        return self.data
